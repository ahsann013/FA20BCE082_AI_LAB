# %% [markdown]
# ### Random Noise Generator

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
values = np.random.randn(50)
plt.plot(values)
plt.xlim(0,50)
plt.title('Random Nose using Test Program')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()
