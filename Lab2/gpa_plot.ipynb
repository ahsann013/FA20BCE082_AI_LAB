# %% [markdown]
# ### GPA Plot Over Time

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gpa = [3.23, 3.12, 3.09, 2.94, 2.6, 2.8, 2.9, 3.1]

# %%
plt.plot(gpa, marker = "o")
plt.title("GPA wrt Semester")
plt.xlabel("Semester")
plt.ylabel("GPA")
plt.show()
